# %%
import cv2, pytesseract, os
import numpy as np
from PIL import Image
import easyocr

# ======================
# [1] Tesseract OCR 준비
# ======================
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
os.environ["TESSDATA_PREFIX"] = r"C:\Program Files\Tesseract-OCR\tessdata"

# PIL로 열기 (한글 경로 문제 해결)
img_path = r"C:\githome\Object_detection\인바디결과2.png"
pil_img = Image.open(img_path)
img = np.array(pil_img)  # numpy 배열 (OpenCV 처리 가능)

# (1) 고해상도 리사이즈
img = cv2.resize(img, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

# (2) 그레이스케일 + Otsu 이진화
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# (3) 선 제거 (수평 + 수직)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (40, 1))
remove_horizontal = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=2)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 40))
remove_vertical = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=2)

clean = thresh - remove_horizontal - remove_vertical

# (4) Tesseract OCR 실행
tess_config = r'--oem 3 --psm 4'  # 표/단락 모드
tess_text = pytesseract.image_to_string(clean, lang="kor+eng", config=tess_config)

print("===== [Tesseract OCR 결과] =====")
print(tess_text)

# ======================
# [2] EasyOCR 실행
# ======================
reader = easyocr.Reader(['ko', 'en'])
results = reader.readtext(img)  # numpy 배열 전달 (한글 경로 문제 방지)

print("\n===== [EasyOCR 결과] =====")
for res in results:
    print(res[1])
# Out:
# ===== [Tesseract OCR 결과] =====
# ZERO
#
# | a Seey
#
# 셀스
# Le
#
# VS:
#
# 2 네
# = &
#
# ata a
# nes”
#
# a
# 4g
#
# ors nek vce Me
# '-「 」1* 이 면기 a 8
# 삐 603 “1
# Ol 1} 81M 3 ay '
#
# 6 29 바 ey a te 포만
# lg 노 빼 뱃 이 100/ 정 옥 넘 옥 A wel 부부
# om = TMS cs 2 lee
# Sr ie 2이 | een
#
# ARE ‘8.2 oe,
# (2s 네 스 조 .질 Mi ks
# 개 01 거
# ABZ, Ali 논
# = , , . ” ; 〉 ; ; , , 삐 으 조 | : 테 휴
# 폭율  ——— a meee ix ci Eas "
# 리드 | Ol 7 SS
# re ame 1 0 ree ie 빼 1 im i gs 애 각 호 ees
# 테 I ] ie 111 = 빼 ㅡㅡ
# ㅡ ： ae ： ; ' ㅣ ' ' ㅣ nade vee 을 갑스
# =F on Se C7 | ae _ 띠 퀴 . a J 빼 ㅡㅡ
# Whtriae aa LEWIS 3 Wek a ita 0 느
#
# 매 아 펴 개
#
# nme ay GRR mens Brig
#
# [ 겜넵뭄웹 iy
#
# lesa ae: NS maim 데기 . 태괴 . 2 소 별 온드 9s @ Gre
# simi ea | [ ' 8
# ; , ㅣ ： ： : ' : 계 든 툴 로 도 다
# wal aE cs IM OEE SAL a
# Ba) [ : 2 = vey ms
# ps : eae BE 기 Bw rite Hs
#
# si Lo} AB ied
# 타 제 자 우 르 [ 개 심 한 불 규형
# 다구 개 부구 320020 Sia : 래래 :
# ree de SB: AER 를 BAS
# , , . , " ; ” ; ; , 0 as OSG vam kets et Ay
# 2 「 ae) rut ig" 삐 가 wim wer te mnie. ane Peas a
# (wel Ｌ 1 ㄴ ae
# of} 1 Ｌ 종 1
# —— . 비 { 닙 , 17 — Oe (ode
# << om ani 1 [ 이 mall KEY Ss . eee
# kg i 1 fest 14 4) pe Tee
# il 1 Ｌ 개 3] 3} [ ; 그 ne COOLED
# 를]_콕꿰멜!묻삐삐l ive A) : ie 디 『 도 드 Ｌ "
# ir a ; eel 느 . . , :
# 애
# 배 ， 기 "
# — i it iat rat is wr ts
# Ko} ] [
# (eal [
# — ; " ' ; " ' . Ls
# Dt [ | EE 객 ㅋ & aa om IY 잔 i 「 | [
# ko : 네 포 이 수 뇌 i ㅣ :
# eat, ] 빈 a ' |
# 1 추 내 사 르 WOE 100 ) TeERLeNe
# 니 1 4| { 방4 기
# ， 5 소토
# = Ae hem! 3 | 할아 :
#
# 1 Se
#
# " Tak.
#
# ~~ A TT ced 1 ear 뽀 BR | 즐 Ue 뽀 ON I BUR I ue ㅡ
# ee 란 트 PO 직 ] 08 빌 리우
# .1 . : Cleve cmd EY 1 LSet Le
# SX Bey EIS 프 ㅣ 비 예 에
# pat rte Sick WBE) wie
# 4 eh) Sees mele sii
# 157 다기 BIOs
# 28
# rie ~
# OO ee .
# MET el.
#
# wails me
#
# AE 대
#
# Mls WASIS  BstMl
# cede 2a edele
#
# (35 14) MVUME ESS evals SiS AVOI ASyle
# >
#
# OS (16)
#
# | ]
#
# 17
#
# 이블 . 타 티 이겨 우등 Searuz | 11 데 Gs5E5 OR U5
#
# Z: 276.34%
#
#
# ===== [EasyOCR 결과] =====
# 신운서 IO18YIF
# 소중한메디켜어
# 00257161
# ZeTTA File-Gatoway
# 'hriiDody
# [cc규27383367
# O9a6ir
# [InBody570]
# SS:L
# 회원번호
# 신장
# 나이
# 성별
# 검사일시
# Img32
# 257161
# 147.3cm
# 18
# 여성
# 2022.02.09
# 10.40
# (신문시)
# 체성분분석
# Body Composition Amalysis
# 순정치
# 청소로
# 근육량
# 제방량
# 체중
# 체수분
# 23.5
# 인바디점수
# rbosy Scoc
# ToulBdy Wulet
# (23.2~28.4)
# 23.5
# 30.2
# 단백질
# 6.3
# (29.8~36.4)
# 32.1
# 70/100 점
# (kg)
# Woein
# (6.2~7.6)
# (31.6~38.6)
# 49.7
# 무기질
# 2.29
# Uo tCs
# (38.8~52.4)
# 체성분 종합점수입니다. 근육이 매우 망은 경우
# Mineraly
# (kg)
# (2.15~2.63)
# 100점을 넘울 수 있습니다.
# 체지방
# (kg)
# 17.6
# 체중조절
# Wi어A Camvol
# Byral Mrss
# (9.1~14.6)
# 적정체중
# 45.6 kg
# 골격근 지방분석 Muscle-Fat Analysis
# 체중조절
# 4. 1
# kg
# 지방조절
# 7.1
# kg
# 표준이하
# 표준
# 표준이상
# 근육조절
# +3.0 kg
# 체중
# 55
# 70
# 85
# 100
# 115
# 130
# 145
# 160
# 175
# 190
# '2053
# (kg)
# Weiyhi
# 49.7
# 영양평가
# Yuliiol Lvalu mion
# 골격근량
# 70
# 80
# 90
# 100
# 110
# 120
# 130
# 140
# 150
# 60
# 170
# 단백질
# 미양호
# D부족
# (kg)
# Skclcul Muxle Ma
# 17.1
# 무기질
# 미양호
# 다부족
# 체지방량
# (kg)
# 40
# 60
# 80
# 100
# 160
# 220
# 280
# 340
# 400
# 460
# 520
# BdyFal Mw
# 17.6
# 체지방
# 미양호
# D부족
# p과다
# 비만평가 ocsty
# Ealuciom
# 비만분석 Obesity Analysis
# BMI
# @표준
# [저체중
# [과체중
# 표준이하
# 표준
# 표준이상
# p심한과체중
# BMI
# 10.0
# 15.0
# 18 5
# 21.0
# 250
# 300
# 350
# 40.0
# 450
# 50.0
# 55.0
# 체지방물
# D표준
# D경도비만
# 비비만
# Boy Mas Indes
# (kglm)
# 22.9
# 체지방물
# 80
# 130
# 180
# 230
# 28.0
# 330
# 380
# 430
# 48.0
# 530
# 58.0
# 신체균형평가
# Vody Walurc Lynlumrea
# Percemi BxyFar
# 35.4
# 상체좌우
# 비균형
# [약한불균형 D심한불균형
# 하체좌우
# @균형
# 미약한물균형 D심한물균형
# 부위별근육분석 Scgmental Lcamn Analysis
# 표준체중기준
# {
# 현재체중기준
# 상체하체
# @균형
# 미약한불균형 [심한불균형
# 표준이하
# 표준
# 표준이상
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 부위별체지방분석
# ScatiatalFi unhys
# 오른팔
# (kg)
# 1.47
# Righi Am
# (%)
# 86.1
# 오른팔
# (1.2 kg)
# 155.4%6
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# '240
# 왼팔
# (kg)
# 1.44
# 왼팔
# (1.2 kg)
# 157.0%6
# LeivArW
# (%)
# 84.3
# 몸통
# (8.6 kg)
# 200.7%6
# 70
# 80
# 90
# 10O
# 110
# 120
# 130
# 140
# 150
# 60
# 170
# 몸통
# (kg)
# 14.6
# 오른다리
# (2.8 kg)
# 143,20
# Trunk
# (%)
# 94.1
# 원다리
# (2.8 kg)
# 143.80
# 70
# 80
# 9O
# 100
# 110
# 120
# 130
# 140
# 150
# 160
# 170
# 오른다리
# (kg)
# 4.46
# 연구항목
# Kocach Piindas
# RighiLc8
# %)
# 82.5
# 세포내수분
# 14.6 L
# 14.4~17.6
# 70
# 80
# 90
# 100
# 0
# 120
# 130
# 140
# 150
# 160
# 170
# 원다리
# (kg)
# 4.60
# 세포외수분
# 8.9 L
# 8.8~10.8
# Lei
# (%)
# 85.1
# 기초대사량
# 1063 kcal
# 1114~1279
# 복부지방률
# 0.84
# 0.75~0.85
# 세포외수분비분석 ECW Ratio Analysis
# 내장지방레벌
# 8
# 1~9
# 표준이하
# 표준
# 표준이상
# 비만도
# 109 %
# 90-110
# 0320
# 0 340
# 0360
# 0380
# 0 390
# 0400
# 0410
# 0420
# 0430
# 0440
# 0450
# 세포외수분비
# 골무기질량
# 1.88 kg
# 1.76~2.16
# ECW Ratro
# 0.378
# 체세포량
# 20.9 kg
# 20.6~25.2
# 상원위팔둘레
# 28.4 cm
# 신체변화 Body Composition History
# 상원위팔근육둘레
# 23.6 cm
# 체중
# (kg)
# 49.7
# SMI
# 5.5 kgym
# Weiehi
# 임피던스 uctarc
# 골격근량
# (kg)
# 17.1
# RA
# LA
# IK
# KL
# LL
# Skelcul Muxle Mas
# Ze)
# 51z] 460.4
# 470.6
# 29.9
# 352.8
# 330 5
# 5011z] 420.4
# 431.9
# 26.1
# 316.2
# 297.1
# 체지방물
# (%)
# 35.4
# 5OOuiz 361.4
# 372.6
# 19.9
# 273.4
# 257.0
# Perem BodyFi
# 세포외수분비
# 0.378
# FCW Ratio
# 220209
# 벤최근
# D
# 전체
# 1030
# WCI27
# Ver LoownBodyi203207
# S6ov909233
# Cooyigr C1996-Dy hBody Co Lld Nrgrsresehed
# BR-Koe3-03Cs0128
# VV : 255
# 2: 276.3400
# (%)
# LeV
